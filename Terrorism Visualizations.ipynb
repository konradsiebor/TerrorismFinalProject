# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
terrorism = pd.read_csv('globalterrorism.csv', encoding='ISO-8859-1' )
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
terrorism.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %%
terrorism.head()
# Out:
#         eventid  iyear  imonth  iday  ... INT_IDEO  INT_MISC INT_ANY  related
# 0  197000000001   1970       7     2  ...        0         0       0      NaN
# 1  197000000002   1970       0     0  ...        1         1       1      NaN
# 2  197001000001   1970       1     0  ...       -9         1       1      NaN
# 3  197001000002   1970       1     0  ...       -9         1       1      NaN
# 4  197001000003   1970       1     0  ...       -9         1       1      NaN
#
# [5 rows x 135 columns]

# %%
labels = terrorism["weapdetail"].unique()
labels
# Out:
# array([nan, 'Explosive', 'Incendiary', ...,
#        'More than 10 mortars were used in the attack.',
#        'A 9-mm carbine rifle was used in the attack.',
#        'An explosive device containing a detonating cord, a battery, and a blasting cap was used in the attack.'],
#       dtype=object)

# %%
plt.rcParams["figure.figsize"] = (9, 7)

plt.pie(terrorism["weapdetail"].value_counts().nlargest(10), labels=terrorism["weapdetail"].value_counts().nlargest(10).index)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
plt.pie(terrorism["attacktype1_txt"].value_counts().nlargest(7), labels=terrorism["attacktype1_txt"].value_counts().nlargest(7).index)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
plt.pie(terrorism["targtype1_txt"].value_counts().nlargest(10), labels=terrorism["targtype1_txt"].value_counts().nlargest(10).index)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
 sns.heatmap(terrorism.corr())

# %%
terrorism.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %%
terrorism["nkill"].mean()
# Out:
# 2.4032722986614385

# %%
terrorism["nkill"].std()
# Out:
# 11.545740560321697

# %%
terrorism["nkill"][terrorism["nkill"] == 0].count()
# Out:
# 88149

# %%
terrorism["nkill"][terrorism["nkill"] == 0].count()
# Out:
# 88149

# %%
terrorism["nkill"].nlargest().values
# Out:
# array([1570., 1384., 1383., 1180.,  953.])
